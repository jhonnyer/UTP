# %% [markdown]
# # Titulo
# ## Semititulo
# ### Titulo mas pequeño
# * Punto 1
# * Punto 2
#
# **Texto en negrita**
#
# *Texto en italica*

# %% [markdown]
# # Codigo de latex ejemplo
# $\int_0^\infty x^{-2}dx$

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
# importamos una de las librerías más útiles 
# para nosotros: numpy (numerical python) 
import numpy

# Cálculo del area de un círculo de radio 5
r = 5
area = numpy.pi * r ** 2
print("El area del círculo es ", round(area,2))
# Out:
# El area del círculo es  78.54

# %% [markdown]
# | Radioisótopo | Nombre | Semiperíodo |
# | :---: | :--- | ---: |
# | Tc-99m | Tecnecio | 6.02 horas |
# | Y-133 | Yodo | 8.02 días |
# | Columna centrada | Alineación izquierda | Alineación derecha |

# %% [markdown]
# Listas ordenadas
# Prefijo: número y un punto, o también número y un paréntesis de cierre. La indentación determina items de la misma categoría. La numeración de la lista es automática, el primer elemento es el que determina el número inicial, y los siguientes se incrementan en uno. Al indentar cambia el tipo de la numeración.
#
# 3. Item 1
# 1. Item 2
# 1. Item 3
#     4. Subitem 1
#     3. Subitem 2
#        8. Subsubitem 1
#            8. Subsubsubsub
#     1. Subitem 3
# La lista anterior se ve así:
#
# Item 1
# Item 2
# Item 3
# Subitem 1
# Subitem 2
# Subsubitem 1
# Subsubsubsub
# Subitem 3

# %% [markdown]
# Enlaces
# Enlace de python
#
#
# Python:
# [python](https://www.python.org/)

# %% [markdown]
# Imágenes
# El formato para ingresar imágenes es casi idéntico al anterior (![título](path_to/nombreDeLaImagen.png)), el signo de admiración indica que se trata de la inserción de una imagen (si no se usa este signo entonces queda un link a la imagen):
#
# Código: ![Woody y Buzz](https://www.adslzone.net/app/uploads-adslzone.net/2019/04/borrar-fondo-imagen.jpg)
# ![Imagen](imagen.png)

# %%
from IPython.display import Image
Image(filename="imagen.png",width=400, height=400)

# %% [markdown]
# <img src='../imagen_prueba.png'>

# %%
from IPython.display import YouTubeVideo

video=YouTubeVideo('7XO1AzwkPPE')
display(video)
