# %% [markdown]
# # Analisis del problema
#
# ## Variables entrada
#
# 1. ingresos
# 2. gastos
#
# # Procedemiento
#
# ## Evaluar datos de entrada
#
# 1. Si los ingresos son mayores que los gastos, voy a tener beneficios o ganancias
#
# 2. Sino, los gastos son mayores que los ingresos, por lo tanto tenemos pérdidas
#
# # Salidas de datos
# 1. Beneficios
# 2. Perdidas
#
#
# # Diseñar solución
#
# ## Algoritmo
#
# *Inicio*
# 1. Leer los ingresos o ventas de la tienda
# 2. Leer los gastos de la tienda
# 3. Comparar la variable de ingreso y la variable de gastos cual es mayor, menor o igual
#     1. Si los ingresos son mayores o igual a los gastos hay ganancia
#     2. Si los gastos son mayores a los ingresos, hay perdidas
# 3. Mostrar resultado
# *FIN*

# %% [markdown]
# # Analisis del problema
#
# ## Variables de entrada
#
# 1. Dinero de la cuenta
# 2. Dinero a retirar
# 3. Dinero del cajero
#
# ## Procedemiento
#
# 1. Si tiene dinero en la cuenta, puede retirar dinero, sino debe indicar que no tiene saldo en la cuenta y mostrar el dinero disponible
# 2. realizar retiro minimo 2 veces
# 3. Verificar que el cajero tenga el dinero disponible
#
# ## Salidas
#
# 1. Nuevo saldo si retira dinero
# 2. Dinero retirado
#
# # Algoritmo
#
# *Inicio*
#
# 1. Leer dinero del cajero
# 2. Leer dinero de la cuenta
# 3. Leer dinero a retirar
# 4. Verificar dinero del cajero
#     1. Si el cajero tiene dinero
#         1.1. verificar dinero de la cuenta
#             1. Si tiene saldo suficiente
#                 a. puede retirar
#                 b. Muestra el valor retirado
#                 c. Muestra el nuevo saldo en la cuenta
#                 d. Volver  a pedir otro valor a retirar
#             2. Sino tiene, no puede retirar
#                 b. Muestra mensaje de error y no puede retirar dinero
#                 a. Muestra dinero que tiene en la cuenta
#     2. El cajero no tiene dinero
#            1. Mensaje de error, No hay dinero suficiente en el cajero
#
# *Fin*
